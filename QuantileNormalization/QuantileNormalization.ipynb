# %% [markdown]
# ### Initialization

# %%
import numpy as np
import pandas as pd

# %%
def PercentileNormalization(matrix, p):
    """
    Percentile normalization
    
    Parameters
    ----------
    matrix : array_like
        Matrix to normalize.
    p : float in range of [0,100]
        Percentile to compute, which must be between 0 and 100 inclusive.
        
    Returns
    -------
    array_like
        Normalized matrix.
    """
    return matrix / np.percentile(matrix[~np.all(matrix == 0, axis=1)], p, axis=0)

# %%
def QuartileNormalization(matrix, q):
    """
    Quartile normalization
    
    Parameters
    ----------
    matrix : array_like
        Matrix to normalize.
    q : string from set = {"upper", "lower", "median"}
        The names of quartiles to compute in accordance:
        "upper" = 75,
        "lower" = 25,
        "median" = 50.
        
    Returns
    -------
    array_like
        Normalized matrix.
    """
    d = {"upper": 75, "lower": 25, "median": 50}
    return PercentileNormalization(matrix, d[q])

# %% [markdown]
# ### Numeric test

# %%
matrix = pd.read_table('../test_data/dataset.txt', sep=' ', header=None)

# %% [markdown]
# Before:

# %%
matrix
# Out:
#      0   1  2
# 0    5  10  1
# 1   10  20  2
# 2    1   2  5
# 3  353   0  2
# 4    7   7  7
# 5    8   9  8

# %% [markdown]
# After:

# %%
normal_matrix = QuartileNormalization(matrix, 'lower')
normal_matrix
# Out:
#            0         1    2
# 0   0.909091  3.076923  0.5
# 1   1.818182  6.153846  1.0
# 2   0.181818  0.615385  2.5
# 3  64.181818  0.000000  1.0
# 4   1.272727  2.153846  3.5
# 5   1.454545  2.769231  4.0

# %% [markdown]
# ### Perfomance test

# %%
matrix = np.random.randint(0, 1000, size=(3000, 5000))

print("QuartileNormalization - ", end="")
# %time normal_matrix = QuartileNormalization(matrix, 'upper')
# Out:
# QuartileNormalization - Wall time: 671 ms

# %% [markdown]
# Read matrix from .csv file and normalize it:

# %%
data = pd.read_csv("../data/srr1784310_subset.csv", index_col=0)
data.head()
# Out:
#             AGCACCTCTAAGCTTCT  GAGACAGATACGCTAGTC  CCAACCGTCGATTGAT  \
# uc009vfc.1                 49                  50                48
# uc009vew.1                 50                  45                57
# Lars2                      90                 110                89
# Hsp90ab1                  143                 103               104
# Ptma                       67                 136                85
#
#             TGATATTGCCTAACAATCC  ATATGCATACTAGGAT  GACTAGACCCAAACGCCT  \
# uc009vfc.1                   33                47                  42
# uc009vew.1                   28                72                  59
# Lars2                       113                77                  81
# Hsp90ab1                    112               111                  90
# Ptma                         66                96                  73
#
#             ACCTTGCCAAACCTCC  GATGACCCTCACCTTGCC  AATATACCTATATGCAT  \
# uc009vfc.1                40                  21                171
# uc009vew.1                44                  40                155
# Lars2                     57                  91                 62
# Hsp90ab1                  94                 125                 55
# Ptma                      74                  80                 34
#
#             GATAACCATCCCTCGTCT        ...         TGAATGCATGGGGTTAGTG  \
# uc009vfc.1                  28        ...                           4
# uc009vew.1                  58        ...                          10
# Lars2                       71        ...                          11
# Hsp90ab1                    84        ...                          12
# Ptma                        64        ...                          11
#
#             TGAAGCGTAGGGAACGATT  CCCATCTGTTATCTGT  ATCATGAGGTAGTCTAG  \
# uc009vfc.1                    1                 3                  5
# uc009vew.1                    2                 4                  3
# Lars2                        14                15                 10
# Hsp90ab1                     13                11                  6
# Ptma                         10                 5                  3
#
#             TGATACGTGCTTGACGGAC  AGGTCACAGGCATGGGT  TGAGTTCTGTTGGGAACCT  \
# uc009vfc.1                    8                  5                    2
# uc009vew.1                    1                  4                    4
# Lars2                        10                 17                   18
# Hsp90ab1                     15                  3                   14
# Ptma                         10                  7                   14
#
#             GAGGTCCCTTCGACTCCT  GATTAGACCGGCTTAC  GTTCAACTGGTTAGTG
# uc009vfc.1                   3                 4                12
# uc009vew.1                   6                 5                10
# Lars2                       20                 5                24
# Hsp90ab1                     9                10                11
# Ptma                         7                16                 8
#
# [5 rows x 900 columns]

# %%
normal_data = QuartileNormalization(data, 'upper')
normal_data.head()
# Out:
#             AGCACCTCTAAGCTTCT  GAGACAGATACGCTAGTC  CCAACCGTCGATTGAT  \
# uc009vfc.1           3.500000            3.333333          3.428571
# uc009vew.1           3.571429            3.000000          4.071429
# Lars2                6.428571            7.333333          6.357143
# Hsp90ab1            10.214286            6.866667          7.428571
# Ptma                 4.785714            9.066667          6.071429
#
#             TGATATTGCCTAACAATCC  ATATGCATACTAGGAT  GACTAGACCCAAACGCCT  \
# uc009vfc.1             2.693878          3.615385            3.818182
# uc009vew.1             2.285714          5.538462            5.363636
# Lars2                  9.224490          5.923077            7.363636
# Hsp90ab1               9.142857          8.538462            8.181818
# Ptma                   5.387755          7.384615            6.636364
#
#             ACCTTGCCAAACCTCC  GATGACCCTCACCTTGCC  AATATACCTATATGCAT  \
# uc009vfc.1          3.636364            1.866667          14.250000
# uc009vew.1          4.000000            3.555556          12.916667
# Lars2               5.181818            8.088889           5.166667
# Hsp90ab1            8.545455           11.111111           4.583333
# Ptma                6.727273            7.111111           2.833333
#
#             GATAACCATCCCTCGTCT        ...         TGAATGCATGGGGTTAGTG  \
# uc009vfc.1            3.111111        ...                         2.0
# uc009vew.1            6.444444        ...                         5.0
# Lars2                 7.888889        ...                         5.5
# Hsp90ab1              9.333333        ...                         6.0
# Ptma                  7.111111        ...                         5.5
#
#             TGAAGCGTAGGGAACGATT  CCCATCTGTTATCTGT  ATCATGAGGTAGTCTAG  \
# uc009vfc.1                  0.5               1.5                2.5
# uc009vew.1                  1.0               2.0                1.5
# Lars2                       7.0               7.5                5.0
# Hsp90ab1                    6.5               5.5                3.0
# Ptma                        5.0               2.5                1.5
#
#             TGATACGTGCTTGACGGAC  AGGTCACAGGCATGGGT  TGAGTTCTGTTGGGAACCT  \
# uc009vfc.1                  4.0                2.5                  1.0
# uc009vew.1                  0.5                2.0                  2.0
# Lars2                       5.0                8.5                  9.0
# Hsp90ab1                    7.5                1.5                  7.0
# Ptma                        5.0                3.5                  7.0
#
#             GAGGTCCCTTCGACTCCT  GATTAGACCGGCTTAC  GTTCAACTGGTTAGTG
# uc009vfc.1                 1.5               2.0               6.0
# uc009vew.1                 3.0               2.5               5.0
# Lars2                     10.0               2.5              12.0
# Hsp90ab1                   4.5               5.0               5.5
# Ptma                       3.5               8.0               4.0
#
# [5 rows x 900 columns]
