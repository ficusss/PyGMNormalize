# %% [markdown]
# ### Initialization

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <div style="color:red">
# Цитата из статьи:
# Here, the scale factor is calculated from the 75th percentile of the counts for each library after removing transcripts, which are zero in **all** libraries.
# </div>

# %%
def QuartileNormalization(matrix, q):
    """
    Quantile normalization
    
    Parameters
    ----------
    matrix : array_like
        Matrix to normalize.
    q : float in range of [0,100]
        Percentile to compute, which must be between 0 and 100 inclusive.
        
    Returns
    -------
    array_like
        Normalized matrix.
    """
    return matrix / np.percentile(matrix[~np.any(matrix == 0, axis=1)], q, axis=0)

# %% [markdown]
# ### Numeric test

# %%
matrix = pd.read_table('../test_data/dataset.txt', sep=' ', header=None)

# %% [markdown]
# Before:

# %%
matrix
# Out:
#      0   1  2
# 0    5  10  1
# 1   10  20  2
# 2    1   2  5
# 3  353   0  2
# 4    7   7  7
# 5    9   9  9
# 6    8   9  8
# 7    1   4  1

# %% [markdown]
# After:

# %%
normal_matrix = QuartileNormalization(matrix, 75)
normal_matrix
# Out:
#            0         1         2
# 0   0.588235  1.052632  0.133333
# 1   1.176471  2.105263  0.266667
# 2   0.117647  0.210526  0.666667
# 3  41.529412  0.000000  0.266667
# 4   0.823529  0.736842  0.933333
# 5   1.058824  0.947368  1.200000
# 6   0.941176  0.947368  1.066667
# 7   0.117647  0.421053  0.133333

# %% [markdown]
# ### Perfomance test

# %%
matrix = np.random.randint(0, 1000, size=(3000, 5000))

print("QuartileNormalization - ", end="")
# %time normal_matrix = QuartileNormalization(matrix, 75)
# Out:
# QuartileNormalization - Wall time: 137 ms

# %% [markdown]
# Read matrix from .csv file and normalize it:

# %%
data = pd.read_csv("../data/srr1784310_subset.csv", index_col=0)
data.head()
# Out:
#             AGCACCTCTAAGCTTCT  GAGACAGATACGCTAGTC  CCAACCGTCGATTGAT  \
# uc009vfc.1                 49                  50                48
# uc009vew.1                 50                  45                57
# Lars2                      90                 110                89
# Hsp90ab1                  143                 103               104
# Ptma                       67                 136                85
#
#             TGATATTGCCTAACAATCC  ATATGCATACTAGGAT  GACTAGACCCAAACGCCT  \
# uc009vfc.1                   33                47                  42
# uc009vew.1                   28                72                  59
# Lars2                       113                77                  81
# Hsp90ab1                    112               111                  90
# Ptma                         66                96                  73
#
#             ACCTTGCCAAACCTCC  GATGACCCTCACCTTGCC  AATATACCTATATGCAT  \
# uc009vfc.1                40                  21                171
# uc009vew.1                44                  40                155
# Lars2                     57                  91                 62
# Hsp90ab1                  94                 125                 55
# Ptma                      74                  80                 34
#
#             GATAACCATCCCTCGTCT        ...         TGAATGCATGGGGTTAGTG  \
# uc009vfc.1                  28        ...                           4
# uc009vew.1                  58        ...                          10
# Lars2                       71        ...                          11
# Hsp90ab1                    84        ...                          12
# Ptma                        64        ...                          11
#
#             TGAAGCGTAGGGAACGATT  CCCATCTGTTATCTGT  ATCATGAGGTAGTCTAG  \
# uc009vfc.1                    1                 3                  5
# uc009vew.1                    2                 4                  3
# Lars2                        14                15                 10
# Hsp90ab1                     13                11                  6
# Ptma                         10                 5                  3
#
#             TGATACGTGCTTGACGGAC  AGGTCACAGGCATGGGT  TGAGTTCTGTTGGGAACCT  \
# uc009vfc.1                    8                  5                    2
# uc009vew.1                    1                  4                    4
# Lars2                        10                 17                   18
# Hsp90ab1                     15                  3                   14
# Ptma                         10                  7                   14
#
#             GAGGTCCCTTCGACTCCT  GATTAGACCGGCTTAC  GTTCAACTGGTTAGTG
# uc009vfc.1                   3                 4                12
# uc009vew.1                   6                 5                10
# Lars2                       20                 5                24
# Hsp90ab1                     9                10                11
# Ptma                         7                16                 8
#
# [5 rows x 900 columns]

# %%
normal_data = QuartileNormalization(data, 75)
normal_data.head()
# Out:
#             AGCACCTCTAAGCTTCT  GAGACAGATACGCTAGTC  CCAACCGTCGATTGAT  \
# uc009vfc.1           0.355072            0.342466          0.390244
# uc009vew.1           0.362319            0.308219          0.463415
# Lars2                0.652174            0.753425          0.723577
# Hsp90ab1             1.036232            0.705479          0.845528
# Ptma                 0.485507            0.931507          0.691057
#
#             TGATATTGCCTAACAATCC  ATATGCATACTAGGAT  GACTAGACCCAAACGCCT  \
# uc009vfc.1             0.383721          0.447619            0.466667
# uc009vew.1             0.325581          0.685714            0.655556
# Lars2                  1.313953          0.733333            0.900000
# Hsp90ab1               1.302326          1.057143            1.000000
# Ptma                   0.767442          0.914286            0.811111
#
#             ACCTTGCCAAACCTCC  GATGACCCTCACCTTGCC  AATATACCTATATGCAT  \
# uc009vfc.1          0.430108            0.201923           2.758065
# uc009vew.1          0.473118            0.384615           2.500000
# Lars2               0.612903            0.875000           1.000000
# Hsp90ab1            1.010753            1.201923           0.887097
# Ptma                0.795699            0.769231           0.548387
#
#             GATAACCATCCCTCGTCT        ...         TGAATGCATGGGGTTAGTG  \
# uc009vfc.1            0.333333        ...                    0.333333
# uc009vew.1            0.690476        ...                    0.833333
# Lars2                 0.845238        ...                    0.916667
# Hsp90ab1              1.000000        ...                    1.000000
# Ptma                  0.761905        ...                    0.916667
#
#             TGAAGCGTAGGGAACGATT  CCCATCTGTTATCTGT  ATCATGAGGTAGTCTAG  \
# uc009vfc.1             0.071429          0.250000                1.0
# uc009vew.1             0.142857          0.333333                0.6
# Lars2                  1.000000          1.250000                2.0
# Hsp90ab1               0.928571          0.916667                1.2
# Ptma                   0.714286          0.416667                0.6
#
#             TGATACGTGCTTGACGGAC  AGGTCACAGGCATGGGT  TGAGTTCTGTTGGGAACCT  \
# uc009vfc.1             0.666667           0.357143             0.153846
# uc009vew.1             0.083333           0.285714             0.307692
# Lars2                  0.833333           1.214286             1.384615
# Hsp90ab1               1.250000           0.214286             1.076923
# Ptma                   0.833333           0.500000             1.076923
#
#             GAGGTCCCTTCGACTCCT  GATTAGACCGGCTTAC  GTTCAACTGGTTAGTG
# uc009vfc.1            0.230769          0.307692          1.090909
# uc009vew.1            0.461538          0.384615          0.909091
# Lars2                 1.538462          0.384615          2.181818
# Hsp90ab1              0.692308          0.769231          1.000000
# Ptma                  0.538462          1.230769          0.727273
#
# [5 rows x 900 columns]

# %% [markdown]
# <div style="color:red">
# Эта строчка является валидацией метода. Её потом надо будет вынести в unit-тесты. Для данного метода проверка суммы ничего не даёт - нам нужно проверять квартили. Кстати, лучше делать это через `assert`.
# </div>

# %%
np.isclose(normal_data.sum(axis=0), 1).all()
# Out:
# False
